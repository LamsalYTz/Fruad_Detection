# %%
# save_model.py  
import joblib
import os


best_model = rf   # replace with your chosen best model variable
scaler_obj = scaler   # StandardScaler used during training

os.makedirs("../models", exist_ok=True)
joblib.dump(best_model, "../models/fraud_model.pkl")
joblib.dump(scaler_obj, "../models/scaler.pkl")

print("Saved model -> ../models/fraud_model.pkl")
print("Saved scaler -> ../models/scaler.pkl")
